# %%
import pandas as pd
import numpy as np

df=pd.read_csv("Breast Cancer METABRIC.CSV")

# %%
print(df.head)
print(df.shape)
print(df.columns)
print(df.dtypes)
# Out:
# <bound method NDFrame.head of      Patient ID  Age at Diagnosis Type of Breast Surgery    Cancer Type  \
# 0       MB-0000             75.65             Mastectomy  Breast Cancer
# 1       MB-0002             43.19      Breast Conserving  Breast Cancer
# 2       MB-0005             48.87             Mastectomy  Breast Cancer
# 3       MB-0006             47.68             Mastectomy  Breast Cancer
# 4       MB-0008             76.97             Mastectomy  Breast Cancer
# ...         ...               ...                    ...            ...
# 2504  MTS-T2428             70.05                    NaN  Breast Cancer
# 2505  MTS-T2429             63.60                    NaN  Breast Cancer
# 2506  MTS-T2430               NaN                    NaN  Breast Cancer
# 2507  MTS-T2431               NaN                    NaN  Breast Cancer
# 2508  MTS-T2432               NaN                    NaN  Breast Cancer
#
#                            Cancer Type Detailed Cellularity Chemotherapy  \
# 0              Breast Invasive Ductal Carcinoma         NaN           No
# 1              Breast Invasive Ductal Carcinoma        High           No
# 2              Breast Invasive Ductal Carcinoma        High          Yes
# 3     Breast Mixed Ductal and Lobular Carcinoma    Moderate          Yes
# 4     Breast Mixed Ductal and Lobular Carcinoma        High          Yes
# ...                                         ...         ...          ...
# 2504                  Invasive Breast Carcinoma         NaN          NaN
# 2505                  Invasive Breast Carcinoma         NaN          NaN
# 2506                  Invasive Breast Carcinoma         NaN          NaN
# 2507                  Invasive Breast Carcinoma         NaN          NaN
# 2508                  Invasive Breast Carcinoma         NaN          NaN
#
#      Pam50 + Claudin-low subtype  Cohort ER status measured by IHC  ...  \
# 0                    claudin-low     1.0                   Positve  ...
# 1                           LumA     1.0                   Positve  ...
# 2                           LumB     1.0                   Positve  ...
# 3                           LumB     1.0                   Positve  ...
# 4                           LumB     1.0                   Positve  ...
# ...                          ...     ...                       ...  ...
# 2504                         NaN     1.0                   Positve  ...
# 2505                         NaN     1.0                   Positve  ...
# 2506                         NaN     NaN                       NaN  ...
# 2507                         NaN     NaN                       NaN  ...
# 2508                         NaN     NaN                       NaN  ...
#
#      Overall Survival Status  PR Status Radio Therapy  \
# 0                     Living   Negative           Yes
# 1                     Living   Positive           Yes
# 2                   Deceased   Positive            No
# 3                     Living   Positive           Yes
# 4                   Deceased   Positive           Yes
# ...                      ...        ...           ...
# 2504                     NaN        NaN           NaN
# 2505                     NaN        NaN           NaN
# 2506                     NaN        NaN           NaN
# 2507                     NaN        NaN           NaN
# 2508                     NaN        NaN           NaN
#
#      Relapse Free Status (Months) Relapse Free Status     Sex  \
# 0                          138.65        Not Recurred  Female
# 1                           83.52        Not Recurred  Female
# 2                          151.28            Recurred  Female
# 3                          162.76        Not Recurred  Female
# 4                           18.55            Recurred  Female
# ...                           ...                 ...     ...
# 2504                         4.93            Recurred  Female
# 2505                        16.18            Recurred  Female
# 2506                          NaN                 NaN  Female
# 2507                          NaN                 NaN  Female
# 2508                          NaN                 NaN  Female
#
#      3-Gene classifier subtype Tumor Size Tumor Stage  Patient's Vital Status
# 0                    ER-/HER2-       22.0         2.0                  Living
# 1        ER+/HER2- High Prolif       10.0         1.0                  Living
# 2                          NaN       15.0         2.0         Died of Disease
# 3                          NaN       25.0         2.0                  Living
# 4        ER+/HER2- High Prolif       40.0         2.0         Died of Disease
# ...                        ...        ...         ...                     ...
# 2504                       NaN       27.0         1.0                     NaN
# 2505                       NaN       28.0         2.0                     NaN
# 2506                       NaN        NaN         0.0                     NaN
# 2507                       NaN        NaN         0.0                     NaN
# 2508                       NaN        NaN         0.0                     NaN
#
# [2509 rows x 34 columns]>
# (2509, 34)
# Index(['Patient ID', 'Age at Diagnosis', 'Type of Breast Surgery',
#        'Cancer Type', 'Cancer Type Detailed', 'Cellularity', 'Chemotherapy',
#        'Pam50 + Claudin-low subtype', 'Cohort', 'ER status measured by IHC',
#        'ER Status', 'Neoplasm Histologic Grade',
#        'HER2 status measured by SNP6', 'HER2 Status',
#        'Tumor Other Histologic Subtype', 'Hormone Therapy',
#        'Inferred Menopausal State', 'Integrative Cluster',
#        'Primary Tumor Laterality', 'Lymph nodes examined positive',
#        'Mutation Count', 'Nottingham prognostic index', 'Oncotree Code',
#        'Overall Survival (Months)', 'Overall Survival Status', 'PR Status',
#        'Radio Therapy', 'Relapse Free Status (Months)', 'Relapse Free Status',
#        'Sex', '3-Gene classifier subtype', 'Tumor Size', 'Tumor Stage',
#        'Patient's Vital Status'],
#       dtype='object')
# Patient ID                         object
# Age at Diagnosis                  float64
# Type of Breast Surgery             object
# Cancer Type                        object
# Cancer Type Detailed               object
# Cellularity                        object
# Chemotherapy                       object
# Pam50 + Claudin-low subtype        object
# Cohort                            float64
# ER status measured by IHC          object
# ER Status                          object
# Neoplasm Histologic Grade         float64
# HER2 status measured by SNP6       object
# HER2 Status                        object
# Tumor Other Histologic Subtype     object
# Hormone Therapy                    object
# Inferred Menopausal State          object
# Integrative Cluster                object
# Primary Tumor Laterality           object
# Lymph nodes examined positive     float64
# Mutation Count                    float64
# Nottingham prognostic index       float64
# Oncotree Code                      object
# Overall Survival (Months)         float64
# Overall Survival Status            object
# PR Status                          object
# Radio Therapy                      object
# Relapse Free Status (Months)      float64
# Relapse Free Status                object
# Sex                                object
# 3-Gene classifier subtype          object
# Tumor Size                        float64
# Tumor Stage                       float64
# Patient's Vital Status             object
# dtype: object

# %%
categorical=df.select_dtypes(include=['object'])
unique= categorical.nunique()
print(unique)

# %%
print(df.describe())
summary_cate=categorical.describe()
print(summary_cate)

# %%
# Example: Check for missing values
missing_summary = df.isnull().sum()
print(missing_summary)
# Out:
# Patient ID                          0
# Age at Diagnosis                   11
# Type of Breast Surgery            554
# Cancer Type                         0
# Cancer Type Detailed               21
# Cellularity                       592
# Chemotherapy                      529
# Pam50 + Claudin-low subtype       529
# Cohort                             11
# ER status measured by IHC          83
# ER Status                          40
# Neoplasm Histologic Grade         121
# HER2 status measured by SNP6      529
# HER2 Status                       529
# Tumor Other Histologic Subtype    135
# Hormone Therapy                   529
# Inferred Menopausal State         529
# Integrative Cluster               529
# Primary Tumor Laterality          639
# Lymph nodes examined positive     266
# Mutation Count                    152
# Nottingham prognostic index       222
# Oncotree Code                       0
# Overall Survival (Months)         528
# Overall Survival Status           528
# PR Status                         529
# Radio Therapy                     529
# Relapse Free Status (Months)      121
# Relapse Free Status                21
# Sex                                 0
# 3-Gene classifier subtype         745
# Tumor Size                        149
# Tumor Stage                       721
# Patient's Vital Status            529
# dtype: int64

# %%
missing_percentage = df.isnull().mean() * 100
print(missing_percentage)
# Out:
# Patient ID                         0.000000
# Age at Diagnosis                   0.438422
# Type of Breast Surgery            22.080510
# Cancer Type                        0.000000
# Cancer Type Detailed               0.000000
# Cellularity                       23.595058
# Chemotherapy                      21.084097
# Pam50 + Claudin-low subtype       21.084097
# Cohort                             0.438422
# ER status measured by IHC          3.308091
# ER Status                          1.594261
# Neoplasm Histologic Grade          4.822639
# HER2 status measured by SNP6      21.084097
# HER2 Status                       21.084097
# Tumor Other Histologic Subtype     5.380630
# Hormone Therapy                   21.084097
# Inferred Menopausal State         21.084097
# Integrative Cluster               21.084097
# Primary Tumor Laterality          25.468314
# Lymph nodes examined positive     10.601833
# Mutation Count                     6.058191
# Nottingham prognostic index        8.848147
# Oncotree Code                      0.000000
# Overall Survival (Months)         21.044241
# Overall Survival Status           21.044241
# PR Status                         21.084097
# Radio Therapy                     21.084097
# Relapse Free Status (Months)       4.822639
# Relapse Free Status                0.836987
# Sex                                0.000000
# 3-Gene classifier subtype         29.693105
# Tumor Size                         5.938621
# Tumor Stage                       28.736548
# Patient's Vital Status            21.084097
# dtype: float64

# %%
# !pip install missingno
# Out:
# Requirement already satisfied: missingno in c:\users\itsu\anaconda3\lib\site-packages (0.5.2)
# Requirement already satisfied: numpy in c:\users\itsu\anaconda3\lib\site-packages (from missingno) (1.24.3)
# Requirement already satisfied: matplotlib in c:\users\itsu\anaconda3\lib\site-packages (from missingno) (3.7.2)
# Requirement already satisfied: scipy in c:\users\itsu\anaconda3\lib\site-packages (from missingno) (1.11.1)
# Requirement already satisfied: seaborn in c:\users\itsu\anaconda3\lib\site-packages (from missingno) (0.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\itsu\anaconda3\lib\site-packages (from matplotlib->missingno) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\itsu\anaconda3\lib\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\itsu\anaconda3\lib\site-packages (from matplotlib->missingno) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\itsu\anaconda3\lib\site-packages (from matplotlib->missingno) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\itsu\anaconda3\lib\site-packages (from matplotlib->missingno) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\itsu\anaconda3\lib\site-packages (from matplotlib->missingno) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\itsu\anaconda3\lib\site-packages (from matplotlib->missingno) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\itsu\anaconda3\lib\site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: pandas>=0.25 in c:\users\itsu\anaconda3\lib\site-packages (from seaborn->missingno) (1.5.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\itsu\anaconda3\lib\site-packages (from pandas>=0.25->seaborn->missingno) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in c:\users\itsu\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)

# %%
import missingno as msno

msno.matrix(df)
msno.heatmap(df)
# Out:
# <Axes: >

# %%
#this line is to change an erroneous entry in the 'Cancer Type Detailed' column to NaN 

df.loc[df['Cancer Type Detailed'] == 'Breast', 'Cancer Type Detailed'] = np.nan

# %%
# Save original non-numeric columns
non_numeric_columns = df.select_dtypes(include=['object']).copy()

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\itsu\anaconda3\lib\site-packages (1.3.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.17.3 in c:\users\itsu\anaconda3\lib\site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\itsu\anaconda3\lib\site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\itsu\anaconda3\lib\site-packages (from scikit-learn) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\itsu\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)

# %%
from sklearn.impute import KNNImputer

# %%
# Convert categorical variables to numeric if needed
df_encoded = pd.get_dummies(df, drop_first=False)  # One-hot encoding

# %%
# Initialize KNN Imputer with the number of neighbors (default is 5)
imputer = KNNImputer(n_neighbors=5)

# Apply KNN imputation (returns a numpy array)
df_imputed_array = imputer.fit_transform(df_encoded)

# %%
# Convert the imputed array back to a DataFrame
df_imputed = pd.DataFrame(df_imputed_array, columns=df_encoded.columns)

# If your data originally contained non-numeric columns, you can map them back

# %%
for column in non_numeric_columns.columns:
    related_columns = [col for col in df_imputed.columns if col.startswith(column + "_")]
    print(f"Related columns for {column}: {related_columns}")
# Out:
# Related columns for Patient ID: ['Patient ID_MB-0000', 'Patient ID_MB-0002', 'Patient ID_MB-0005', 'Patient ID_MB-0006', 'Patient ID_MB-0008', 'Patient ID_MB-0010', 'Patient ID_MB-0014', 'Patient ID_MB-0020', 'Patient ID_MB-0022', 'Patient ID_MB-0025', 'Patient ID_MB-0028', 'Patient ID_MB-0035', 'Patient ID_MB-0036', 'Patient ID_MB-0039', 'Patient ID_MB-0045', 'Patient ID_MB-0046', 'Patient ID_MB-0048', 'Patient ID_MB-0050', 'Patient ID_MB-0053', 'Patient ID_MB-0054', 'Patient ID_MB-0056', 'Patient ID_MB-0059', 'Patient ID_MB-0060', 'Patient ID_MB-0062', 'Patient ID_MB-0064', 'Patient ID_MB-0066', 'Patient ID_MB-0068', 'Patient ID_MB-0071', 'Patient ID_MB-0079', 'Patient ID_MB-0081', 'Patient ID_MB-0083', 'Patient ID_MB-0093', 'Patient ID_MB-0095', 'Patient ID_MB-0097', 'Patient ID_MB-0099', 'Patient ID_MB-0100', 'Patient ID_MB-0101', 'Patient ID_MB-0102', 'Patient ID_MB-0106', 'Patient ID_MB-0107', 'Patient ID_MB-0108', 'Patient ID_MB-0109', 'Patient ID_MB-0110', 'Patient ID_MB-0111', 'Patient ID_MB-0112', 'Patient ID_MB-0113', 'Patient ID_MB-0114', 'Patient ID_MB-0115', 'Patient ID_MB-0116', 'Patient ID_MB-0117', 'Patient ID_MB-0119', 'Patient ID_MB-0120', 'Patient ID_MB-0121', 'Patient ID_MB-0122', 'Patient ID_MB-0123', 'Patient ID_MB-0124', 'Patient ID_MB-0125', 'Patient ID_MB-0126', 'Patient ID_MB-0127', 'Patient ID_MB-0128', 'Patient ID_MB-0129', 'Patient ID_MB-0130', 'Patient ID_MB-0131', 'Patient ID_MB-0133', 'Patient ID_MB-0134', 'Patient ID_MB-0135', 'Patient ID_MB-0136', 'Patient ID_MB-0138', 'Patient ID_MB-0139', 'Patient ID_MB-0140', 'Patient ID_MB-0142', 'Patient ID_MB-0143', 'Patient ID_MB-0144', 'Patient ID_MB-0145', 'Patient ID_MB-0146', 'Patient ID_MB-0147', 'Patient ID_MB-0148', 'Patient ID_MB-0149', 'Patient ID_MB-0150', 'Patient ID_MB-0151', 'Patient ID_MB-0152', 'Patient ID_MB-0153', 'Patient ID_MB-0154', 'Patient ID_MB-0155', 'Patient ID_MB-0156', 'Patient ID_MB-0157', 'Patient ID_MB-0158', 'Patient ID_MB-0159', 'Patient ID_MB-0160', 'Patient ID_MB-0162', 'Patient ID_MB-0163', 'Patient ID_MB-0164', 'Patient ID_MB-0165', 'Patient ID_MB-0166', 'Patient ID_MB-0167', 'Patient ID_MB-0168', 'Patient ID_MB-0169', 'Patient ID_MB-0170', 'Patient ID_MB-0171', 'Patient ID_MB-0172', 'Patient ID_MB-0173', 'Patient ID_MB-0174', 'Patient ID_MB-0175', 'Patient ID_MB-0176', 'Patient ID_MB-0177', 'Patient ID_MB-0178', 'Patient ID_MB-0179', 'Patient ID_MB-0180', 'Patient ID_MB-0181', 'Patient ID_MB-0184', 'Patient ID_MB-0185', 'Patient ID_MB-0188', 'Patient ID_MB-0189', 'Patient ID_MB-0191', 'Patient ID_MB-0192', 'Patient ID_MB-0193', 'Patient ID_MB-0194', 'Patient ID_MB-0195', 'Patient ID_MB-0197', 'Patient ID_MB-0198', 'Patient ID_MB-0199', 'Patient ID_MB-0200', 'Patient ID_MB-0201', 'Patient ID_MB-0202', 'Patient ID_MB-0203', 'Patient ID_MB-0204', 'Patient ID_MB-0205', 'Patient ID_MB-0206', 'Patient ID_MB-0207', 'Patient ID_MB-0209', 'Patient ID_MB-0210', 'Patient ID_MB-0211', 'Patient ID_MB-0214', 'Patient ID_MB-0215', 'Patient ID_MB-0218', 'Patient ID_MB-0220', 'Patient ID_MB-0221', 'Patient ID_MB-0222', 'Patient ID_MB-0223', 'Patient ID_MB-0224', 'Patient ID_MB-0225', 'Patient ID_MB-0226', 'Patient ID_MB-0227', 'Patient ID_MB-0228', 'Patient ID_MB-0229', 'Patient ID_MB-0230', 'Patient ID_MB-0231', 'Patient ID_MB-0232', 'Patient ID_MB-0233', 'Patient ID_MB-0234', 'Patient ID_MB-0235', 'Patient ID_MB-0236', 'Patient ID_MB-0238', 'Patient ID_MB-0239', 'Patient ID_MB-0241', 'Patient ID_MB-0242', 'Patient ID_MB-0243', 'Patient ID_MB-0244', 'Patient ID_MB-0245', 'Patient ID_MB-0247', 'Patient ID_MB-0248', 'Patient ID_MB-0249', 'Patient ID_MB-0253', 'Patient ID_MB-0256', 'Patient ID_MB-0257', 'Patient ID_MB-0258', 'Patient ID_MB-0259', 'Patient ID_MB-0260', 'Patient ID_MB-0261', 'Patient ID_MB-0262', 'Patient ID_MB-0263', 'Patient ID_MB-0264', 'Patient ID_MB-0265', 'Patient ID_MB-0266', 'Patient ID_MB-0268', 'Patient ID_MB-0269', 'Patient ID_MB-0270', 'Patient ID_MB-0272', 'Patient ID_MB-0273', 'Patient ID_MB-0275', 'Patien ...
# Related columns for Type of Breast Surgery: ['Type of Breast Surgery_Breast Conserving', 'Type of Breast Surgery_Mastectomy']
# Related columns for Cancer Type: ['Cancer Type_Breast Cancer', 'Cancer Type_Breast Sarcoma']
# Related columns for Cancer Type Detailed: ['Cancer Type Detailed_Breast Angiosarcoma', 'Cancer Type Detailed_Breast Invasive Ductal Carcinoma', 'Cancer Type Detailed_Breast Invasive Lobular Carcinoma', 'Cancer Type Detailed_Breast Invasive Mixed Mucinous Carcinoma', 'Cancer Type Detailed_Breast Mixed Ductal and Lobular Carcinoma', 'Cancer Type Detailed_Invasive Breast Carcinoma', 'Cancer Type Detailed_Metaplastic Breast Cancer']
# Related columns for Cellularity: ['Cellularity_High', 'Cellularity_Low', 'Cellularity_Moderate']
# Related columns for Chemotherapy: ['Chemotherapy_No', 'Chemotherapy_Yes']
# Related columns for Pam50 + Claudin-low subtype: ['Pam50 + Claudin-low subtype_Basal', 'Pam50 + Claudin-low subtype_Her2', 'Pam50 + Claudin-low subtype_LumA', 'Pam50 + Claudin-low subtype_LumB', 'Pam50 + Claudin-low subtype_NC', 'Pam50 + Claudin-low subtype_Normal', 'Pam50 + Claudin-low subtype_claudin-low']
# Related columns for ER status measured by IHC: ['ER status measured by IHC_Negative', 'ER status measured by IHC_Positve']
# Related columns for ER Status: ['ER Status_Negative', 'ER Status_Positive']
# Related columns for HER2 status measured by SNP6: ['HER2 status measured by SNP6_Gain', 'HER2 status measured by SNP6_Loss', 'HER2 status measured by SNP6_Neutral', 'HER2 status measured by SNP6_Undef']
# Related columns for HER2 Status: ['HER2 Status_Negative', 'HER2 Status_Positive']
# Related columns for Tumor Other Histologic Subtype: ['Tumor Other Histologic Subtype_Ductal/NST', 'Tumor Other Histologic Subtype_Lobular', 'Tumor Other Histologic Subtype_Medullary', 'Tumor Other Histologic Subtype_Metaplastic', 'Tumor Other Histologic Subtype_Mixed', 'Tumor Other Histologic Subtype_Mucinous', 'Tumor Other Histologic Subtype_Other', 'Tumor Other Histologic Subtype_Tubular/ cribriform']
# Related columns for Hormone Therapy: ['Hormone Therapy_No', 'Hormone Therapy_Yes']
# Related columns for Inferred Menopausal State: ['Inferred Menopausal State_Post', 'Inferred Menopausal State_Pre']
# Related columns for Integrative Cluster: ['Integrative Cluster_1', 'Integrative Cluster_10', 'Integrative Cluster_2', 'Integrative Cluster_3', 'Integrative Cluster_4ER+', 'Integrative Cluster_4ER-', 'Integrative Cluster_5', 'Integrative Cluster_6', 'Integrative Cluster_7', 'Integrative Cluster_8', 'Integrative Cluster_9']
# Related columns for Primary Tumor Laterality: ['Primary Tumor Laterality_Left', 'Primary Tumor Laterality_Right']
# Related columns for Oncotree Code: ['Oncotree Code_BRCA', 'Oncotree Code_BREAST', 'Oncotree Code_IDC', 'Oncotree Code_ILC', 'Oncotree Code_IMMC', 'Oncotree Code_MBC', 'Oncotree Code_MDLC', 'Oncotree Code_PBS']
# Related columns for Overall Survival Status: ['Overall Survival Status_Deceased', 'Overall Survival Status_Living']
# Related columns for PR Status: ['PR Status_Negative', 'PR Status_Positive']
# Related columns for Radio Therapy: ['Radio Therapy_No', 'Radio Therapy_Yes']
# Related columns for Relapse Free Status: ['Relapse Free Status_Not Recurred', 'Relapse Free Status_Recurred']
# Related columns for Sex: ['Sex_Female']
# Related columns for 3-Gene classifier subtype: ['3-Gene classifier subtype_ER+/HER2- High Prolif', '3-Gene classifier subtype_ER+/HER2- Low Prolif', '3-Gene classifier subtype_ER-/HER2-', '3-Gene classifier subtype_HER2+']
# Related columns for Patient's Vital Status: ["Patient's Vital Status_Died of Disease", "Patient's Vital Status_Died of Other Causes", "Patient's Vital Status_Living"]

# %%
# Map back each original non-numeric column
for column in non_numeric_columns.columns:
    # Get all one-hot encoded columns related to this original column
    related_columns = [col for col in df_imputed.columns if col.startswith(column + '_')]

    # Find the column with the maximum value (imputed category)
    df_imputed[column] = df_imputed[related_columns].idxmax(axis=1)

    # Remove the prefix to restore original category values
    df_imputed[column] = df_imputed[column].str.replace(column + "_", "")
# Out:
# C:\Users\ITSU\AppData\Local\Temp\ipykernel_11048\502359015.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_imputed[column] = df_imputed[column].str.replace(column + "_", "")

# %%
df_final = df_imputed.drop(columns=[col for col in df_imputed.columns if "_" in col])

# %%
print(df_final.head())
# Out:
#    Age at Diagnosis  Cohort  Neoplasm Histologic Grade  \
# 0             75.65     1.0                        3.0
# 1             43.19     1.0                        3.0
# 2             48.87     1.0                        2.0
# 3             47.68     1.0                        2.0
# 4             76.97     1.0                        3.0
#
#    Lymph nodes examined positive  Mutation Count  Nottingham prognostic index  \
# 0                           10.0             5.2                        6.044
# 1                            0.0             2.0                        4.020
# 2                            1.0             2.0                        4.030
# 3                            3.0             1.0                        4.050
# 4                            8.0             2.0                        6.080
#
#    Overall Survival (Months)  Relapse Free Status (Months)  Tumor Size  \
# 0                 140.500000                        138.65        22.0
# 1                  84.633333                         83.52        10.0
# 2                 163.700000                        151.28        15.0
# 3                 164.933333                        162.76        25.0
# 4                  41.366667                         18.55        40.0
#
#    Tumor Stage  ... Integrative Cluster Primary Tumor Laterality  \
# 0          2.0  ...                4ER+                    Right
# 1          1.0  ...                4ER+                    Right
# 2          2.0  ...                   3                    Right
# 3          2.0  ...                   9                    Right
# 4          2.0  ...                   9                    Right
#
#   Oncotree Code Overall Survival Status PR Status Radio Therapy  \
# 0           IDC                  Living  Negative           Yes
# 1           IDC                  Living  Positive           Yes
# 2           IDC                Deceased  Positive            No
# 3          MDLC                  Living  Positive           Yes
# 4          MDLC                Deceased  Positive           Yes
#
#   Relapse Free Status     Sex 3-Gene classifier subtype Patient's Vital Status
# 0        Not Recurred  Female                 ER-/HER2-                 Living
# 1        Not Recurred  Female     ER+/HER2- High Prolif                 Living
# 2            Recurred  Female     ER+/HER2- High Prolif        Died of Disease
# 3        Not Recurred  Female     ER+/HER2- High Prolif                 Living
# 4            Recurred  Female     ER+/HER2- High Prolif        Died of Disease
#
# [5 rows x 34 columns]

# %%
print(df_final.isnull().sum())  # Should return 0 for all columns
# Out:
# Age at Diagnosis                  0
# Cohort                            0
# Neoplasm Histologic Grade         0
# Lymph nodes examined positive     0
# Mutation Count                    0
# Nottingham prognostic index       0
# Overall Survival (Months)         0
# Relapse Free Status (Months)      0
# Tumor Size                        0
# Tumor Stage                       0
# Patient ID                        0
# Type of Breast Surgery            0
# Cancer Type                       0
# Cancer Type Detailed              0
# Cellularity                       0
# Chemotherapy                      0
# Pam50 + Claudin-low subtype       0
# ER status measured by IHC         0
# ER Status                         0
# HER2 status measured by SNP6      0
# HER2 Status                       0
# Tumor Other Histologic Subtype    0
# Hormone Therapy                   0
# Inferred Menopausal State         0
# Integrative Cluster               0
# Primary Tumor Laterality          0
# Oncotree Code                     0
# Overall Survival Status           0
# PR Status                         0
# Radio Therapy                     0
# Relapse Free Status               0
# Sex                               0
# 3-Gene classifier subtype         0
# Patient's Vital Status            0
# dtype: int64

# %%
print("Original shape:", df.shape)
print("After encoding:", df_encoded.shape)
print("After imputation:", df_imputed.shape)
print("After mapping back:", df_final.shape)
# Out:
# Original shape: (2509, 34)
# After encoding: (2509, 2601)
# After imputation: (2509, 2625)
# After mapping back: (2509, 34)

# %%
print(df.columns)  # Check the original columns
# Out:
# Index(['Patient ID', 'Age at Diagnosis', 'Type of Breast Surgery',
#        'Cancer Type', 'Cancer Type Detailed', 'Cellularity', 'Chemotherapy',
#        'Pam50 + Claudin-low subtype', 'Cohort', 'ER status measured by IHC',
#        'ER Status', 'Neoplasm Histologic Grade',
#        'HER2 status measured by SNP6', 'HER2 Status',
#        'Tumor Other Histologic Subtype', 'Hormone Therapy',
#        'Inferred Menopausal State', 'Integrative Cluster',
#        'Primary Tumor Laterality', 'Lymph nodes examined positive',
#        'Mutation Count', 'Nottingham prognostic index', 'Oncotree Code',
#        'Overall Survival (Months)', 'Overall Survival Status', 'PR Status',
#        'Radio Therapy', 'Relapse Free Status (Months)', 'Relapse Free Status',
#        'Sex', '3-Gene classifier subtype', 'Tumor Size', 'Tumor Stage',
#        'Patient's Vital Status'],
#       dtype='object')

# %%
# Add the Patient ID column back from the original DataFrame
df_final['Patient ID'] = df['Patient ID']

# %%
# Align indices
df_final.index = df.index

# %%
print(df['Patient ID'].equals(df_final['Patient ID']))  # Should return True
# Out:
# True

# %%
# Move 'Patient ID' to the first column
columns = ['Patient ID'] + [col for col in df_final.columns if col != 'Patient ID']
df_final = df_final[columns]

# %%
print(df_final.head)
print(df_final.shape)
print(df_final.columns)
print(df_final.dtypes)
# Out:
# <bound method NDFrame.head of      Patient ID  Age at Diagnosis  Cohort  Neoplasm Histologic Grade  \
# 0       MB-0000             75.65     1.0                        3.0
# 1       MB-0002             43.19     1.0                        3.0
# 2       MB-0005             48.87     1.0                        2.0
# 3       MB-0006             47.68     1.0                        2.0
# 4       MB-0008             76.97     1.0                        3.0
# ...         ...               ...     ...                        ...
# 2504  MTS-T2428             70.05     1.0                        1.0
# 2505  MTS-T2429             63.60     1.0                        2.0
# 2506  MTS-T2430             57.20     7.0                        2.2
# 2507  MTS-T2431             49.93     5.8                        2.6
# 2508  MTS-T2432             49.40     7.0                        2.4
#
#       Lymph nodes examined positive  Mutation Count  \
# 0                              10.0             5.2
# 1                               0.0             2.0
# 2                               1.0             2.0
# 3                               3.0             1.0
# 4                               8.0             2.0
# ...                             ...             ...
# 2504                            0.0             2.0
# 2505                            0.0             4.0
# 2506                            0.0             6.0
# 2507                            0.0             7.0
# 2508                            0.0             5.0
#
#       Nottingham prognostic index  Overall Survival (Months)  \
# 0                           6.044                 140.500000
# 1                           4.020                  84.633333
# 2                           4.030                 163.700000
# 3                           4.050                 164.933333
# 4                           6.080                  41.366667
# ...                           ...                        ...
# 2504                        2.540                  12.660000
# 2505                        4.560                  37.440000
# 2506                        2.998                  94.626667
# 2507                        3.284                  94.626667
# 2508                        3.796                 131.753333
#
#       Relapse Free Status (Months)  Tumor Size  ...  Integrative Cluster  \
# 0                          138.650       22.00  ...                 4ER+
# 1                           83.520       10.00  ...                 4ER+
# 2                          151.280       15.00  ...                    3
# 3                          162.760       25.00  ...                    9
# 4                           18.550       40.00  ...                    9
# ...                            ...         ...  ...                  ...
# 2504                         4.930       27.00  ...                    1
# 2505                        16.180       28.00  ...                    1
# 2506                       114.282       15.80  ...                    1
# 2507                       132.954       11.52  ...                    1
# 2508                       122.294       21.00  ...                    1
#
#      Primary Tumor Laterality Oncotree Code Overall Survival Status PR Status  \
# 0                       Right           IDC                  Living  Negative
# 1                       Right           IDC                  Living  Positive
# 2                       Right           IDC                Deceased  Positive
# 3                       Right          MDLC                  Living  Positive
# 4                       Right          MDLC                Deceased  Positive
# ...                       ...           ...                     ...       ...
# 2504                     Left          BRCA                Deceased  Negative
# 2505                     Left          BRCA                Deceased  Negative
# 2506                     Left          BRCA                Deceased  Negative
# 2507                     Left          BRCA                Deceased  Negative
# 2508                     Left          BRCA                Deceased  Negative
#
#      Radio Therapy Relapse Free Status     Sex 3-Gene classifier subtype  \
# 0              Yes        Not Recurred  Female                 ER-/HER2-
# 1              Yes        Not Recurred  Female     ER+/HER2- High Prolif
# 2               No            Recurred  Female     ER+/HER2- High Prolif
# 3              Yes        Not Recurred  Female     ER+/HER2- High Prolif
# 4              Yes            Recurred  Female     ER+/HER2- High Prolif
# ...            ...                 ...     ...                       ...
# 2504            No            Recurred  Female     ER+/HER2- High Prolif
# 2505            No            Recurred  Female     ER+/HER2- High Prolif
# 2506            No        Not Recurred  Female     ER+/HER2- High Prolif
# 2507            No        Not Recurred  Female     ER+/HER2- High Prolif
# 2508            No        Not Recurred  Female     ER+/HER2- High Prolif
#
#      Patient's Vital Status
# 0                    Living
# 1                    Living
# 2           Died of Disease
# 3                    Living
# 4           Died of Disease
# ...                     ...
# 2504        Died of Disease
# 2505        Died of Disease
# 2506        Died of Disease
# 2507        Died of Disease
# 2508        Died of Disease
#
# [2509 rows x 34 columns]>
# (2509, 34)
# Index(['Patient ID', 'Age at Diagnosis', 'Cohort', 'Neoplasm Histologic Grade',
#        'Lymph nodes examined positive', 'Mutation Count',
#        'Nottingham prognostic index', 'Overall Survival (Months)',
#        'Relapse Free Status (Months)', 'Tumor Size', 'Tumor Stage',
#        'Type of Breast Surgery', 'Cancer Type', 'Cancer Type Detailed',
#        'Cellularity', 'Chemotherapy', 'Pam50 + Claudin-low subtype',
#        'ER status measured by IHC', 'ER Status',
#        'HER2 status measured by SNP6', 'HER2 Status',
#        'Tumor Other Histologic Subtype', 'Hormone Therapy',
#        'Inferred Menopausal State', 'Integrative Cluster',
#        'Primary Tumor Laterality', 'Oncotree Code', 'Overall Survival Status',
#        'PR Status', 'Radio Therapy', 'Relapse Free Status', 'Sex',
#        '3-Gene classifier subtype', 'Patient's Vital Status'],
#       dtype='object')
# Patient ID                         object
# Age at Diagnosis                  float64
# Cohort                            float64
# Neoplasm Histologic Grade         float64
# Lymph nodes examined positive     float64
# Mutation Count                    float64
# Nottingham prognostic index       float64
# Overall Survival (Months)         float64
# Relapse Free Status (Months)      float64
# Tumor Size                        float64
# Tumor Stage                       float64
# Type of Breast Surgery             object
# Cancer Type                        object
# Cancer Type Detailed               object
# Cellularity                        object
# Chemotherapy                       object
# Pam50 + Claudin-low subtype        object
# ER status measured by IHC          object
# ER Status                          object
# HER2 status measured by SNP6       object
# HER2 Status                        object
# Tumor Other Histologic Subtype     object
# Hormone Therapy                    object
# Inferred Menopausal State          object
# Integrative Cluster                object
# Primary Tumor Laterality           object
# Oncotree Code                      object
# Overall Survival Status            object
# PR Status                          object
# Radio Therapy                      object
# Relapse Free Status                object
# Sex                                object
# 3-Gene classifier subtype          object
# Patient's Vital Status             object
# dtype: object

# %%
# Example: Check for missing values
missing_summary = df_final.isnull().sum()
print(missing_summary)
# Out:
# Patient ID                        0
# Age at Diagnosis                  0
# Cohort                            0
# Neoplasm Histologic Grade         0
# Lymph nodes examined positive     0
# Mutation Count                    0
# Nottingham prognostic index       0
# Overall Survival (Months)         0
# Relapse Free Status (Months)      0
# Tumor Size                        0
# Tumor Stage                       0
# Type of Breast Surgery            0
# Cancer Type                       0
# Cancer Type Detailed              0
# Cellularity                       0
# Chemotherapy                      0
# Pam50 + Claudin-low subtype       0
# ER status measured by IHC         0
# ER Status                         0
# HER2 status measured by SNP6      0
# HER2 Status                       0
# Tumor Other Histologic Subtype    0
# Hormone Therapy                   0
# Inferred Menopausal State         0
# Integrative Cluster               0
# Primary Tumor Laterality          0
# Oncotree Code                     0
# Overall Survival Status           0
# PR Status                         0
# Radio Therapy                     0
# Relapse Free Status               0
# Sex                               0
# 3-Gene classifier subtype         0
# Patient's Vital Status            0
# dtype: int64

# %%
msno.matrix(df_final)
# Out:
# <Axes: >

# %%
msno.heatmap(df_final)
# Out:
# C:\Users\ITSU\anaconda3\Lib\site-packages\seaborn\matrix.py:309: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# C:\Users\ITSU\anaconda3\Lib\site-packages\seaborn\matrix.py:309: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# <Axes: >

# %%
# Save the cleaned DataFrame to a CSV file
df_final.to_csv('cleaned_data2.csv', index=False)
